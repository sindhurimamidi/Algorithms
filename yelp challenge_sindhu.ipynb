# %%
import pandas as pd
with open('yelp_dataset/yelp_academic_dataset_user.json', 'rb') as f:
    userdata = f.readlines()
userdata = map(lambda x: x.rstrip(), userdata)
userdata_json_str = "[" + ','.join(userdata) + "]"
user_df = pd.read_json(userdata_json_str)

# %%
user_df.head()
# Out:
#    average_stars                                        compliments  \
# 0           4.14  {u'profile': 8, u'cute': 15, u'funny': 11, u'p...
# 1           3.66  {u'profile': 116, u'cute': 206, u'funny': 580,...
# 2           3.60  {u'profile': 9, u'cute': 23, u'funny': 120, u'...
# 3           4.64                                       {u'cute': 2}
# 4           3.80  {u'cute': 2, u'plain': 2, u'writer': 2, u'note...
#
#                                                elite  fans  \
# 0                                       [2005, 2006]    70
# 1  [2005, 2006, 2007, 2008, 2009, 2010, 2011, 201...  1179
# 2  [2005, 2006, 2007, 2008, 2009, 2010, 2011, 201...   100
# 3                                                 []     2
# 4                                             [2005]     4
#
#                                              friends       name  review_count  \
# 0  [rpOyqD_893cqmDAtJLbdog, 4U9kSBLuBDU391x6bxU-Y...     Russel           108
# ...

# %%
import plotly 
plotly.tools.set_credentials_file(username='sindhuri', api_key='z7tquepou5')

# %%
import plotly.plotly as py
from plotly.graph_objs import *

trace0 = Scatter(
    x=[1, 2, 3, 4],
    y=[10, 15, 13, 17]
)
trace1 = Scatter(
    x=[1, 2, 3, 4],
    y=[16, 5, 11, 9]
)
data = Data([trace0, trace1])

py.iplot(data, filename = 'basic-line')

# %%
with open('yelp_dataset/yelp_academic_dataset_review.json', 'rb') as r:
    reviewdata = r.readlines()
reviewdata = map(lambda x: x.rstrip(), reviewdata)
reviewdata_json_str = "[" + ','.join(reviewdata) + "]"
review_df = pd.read_json(reviewdata_json_str)

# %%
review_df.head()
# Out:
#               business_id       date               review_id  stars  \
# 0  5UmKMjUEUNdYWqANhGckJw 2012-08-01  Ya85v4eqdd6k9Od8HbQjyA      4
# 1  5UmKMjUEUNdYWqANhGckJw 2014-02-13  KPvLNJ21_4wbYNctrOwWdQ      5
# 2  5UmKMjUEUNdYWqANhGckJw 2015-10-31  fFSoGV46Yxuwbr3fHNuZig      5
# 3  UsFtqoBl7naz8AVUBZMjQQ 2013-11-08  Di3exaUCFNw1V4kSNW5pgA      5
# 4  UsFtqoBl7naz8AVUBZMjQQ 2014-03-29  0Lua2-PbqEQMjD9r89-asw      3
#
#                                                 text    type  \
# 0  Mr Hoagie is an institution. Walking in, it do...  review
# 1  Excellent food. Superb customer service. I mis...  review
# 2  Yes this place is a little out dated and not o...  review
# 3  All the food is great here. But the best thing...  review
# 4  We checked this place out this past Monday for...  review
#
#                   user_id                                    votes
# 0  PUFPaY9KxDAcGqfsorJp3Q  {u'funny': 0, u'useful': 0, u'cool': 0}
# ...
